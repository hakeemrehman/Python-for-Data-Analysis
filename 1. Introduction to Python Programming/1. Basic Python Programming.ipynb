# %% [markdown]
# # Introduction to Python Programming
# - The idea of PYTHON started in early 1980s.
# - Real Implementation started in 1989.
# - Published in 27 Feb 1991.
# - Developed by Guido van Rossum who was working in National Research Institute Netherlands.
# - Python name was inspired from a TV show Monty Python’s Flying Circus it has nothing to do with snake.

# %% [markdown]
# ## What is Python?
# - Python is a multi-purpose interpreted, object-oriented, and high-level programming language.

# %% [markdown]
# ## Basics of python

# %% [markdown]
# ### 0- Comments
#  - Comments are  description about the code for later analysis and improve readability
#  - In the code bar, use '#' to write comments

# %% [markdown]
# ### 1- Print a String (First python program)

# %%
# Print Function prints whatever in in between () to the output stream
print("This is Hakeem-Ur-Rehman")
# Out:
# This is Hakeem-Ur-Rehman

# %%
"This is Hakeem-Ur-Rehman"
# Out:
# 'This is Hakeem-Ur-Rehman'

# %%
'This is Hakeem-Ur-Rehman'

# %%
'''This is Hakeem-Ur-Rehman'''

# %% [markdown]
# #### Three Ways to write String

# %%
# Can write string in three ways Single quote, double and triple quote
print('Python Programming for Data Analysis')   # String in single quotes
print("Python Programming for Data Science")         # String in double quotes
print("""Python Programming for Machine Learning""")        # string in triple quotes
# Out:
# Python Programming for Data Analysis
# Python Programming for Data Science
# Python Programming for Machine Learning

# %% [markdown]
# #### Errors Identification

# %%
# Print string as error message
frint('Python Programming for Data Analysis') # 'frint' is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\1. University Teaching Data\9. PU-CSAS\2. Python Programming for Data Analysis\1. Basic Python Programming.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/e%3A/1.%20University%20Teaching%20Data/9.%20PU-CSAS/2.%20Python%20Programming%20for%20Data%20Analysis/1.%20Basic%20Python%20Programming.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Print string as error message
# ----> <a href='vscode-notebook-cell:/e%3A/1.%20University%20Teaching%20Data/9.%20PU-CSAS/2.%20Python%20Programming%20for%20Data%20Analysis/1.%20Basic%20Python%20Programming.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> frint('Python Programming for Data Analysis') # 'frint' is not defined
#
# NameError: name 'frint' is not defined

# %%
# Built-in error message
print('Python Programming for Data Analysis)
# Out:
#   Cell In[5], line 2
#     print('Python Programming for Data Analysis)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# ### Keywords in Python
# - Keywords are reserved words in python.
# - We can’t use a keyword as variable name.
# - Keywords are case sensitive.
#
# ![1. Python-Keywords.png](<attachment:1. Python-Keywords.png>)

# %%
import keyword as kw
print(kw.kwlist)
len(kw.kwlist)
print("Total number of keyword are:",len(kw.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# Total number of keyword are: 35

# %% [markdown]
# ### 2- Variables in Python
# - Varibles are the containers or objects  containing values/data.
#
# **Rules For naming variables**
# - Do not use reserved keywords.
# - No spaces are allowed in variable name
# - Variable name start with string, or underscore.
# - Variable name cannot be initiated with a number.
# - Variable name short and descriptive
# - Variable names are case sentive: lower case will be considered lower and higher case will considered higher

# %%
# String variable
var1 = "Hakeem"
var1
# Out:
# 'Hakeem'

# %%
1var1 = "Hakeem" # Give error becasue Variable name cannot be initiated with a number.
# Out:
#   Cell In[5], line 1
#     1var1 = "Hakeem" # Give error becasue Variable name cannot be initiated with a number.
#     ^
# SyntaxError: invalid decimal literal

# %%
# integer variable
var2 = 3
var2

# %%
# If we assign another value to the number variable it will override the previous one
# Because python execute code from top to bottom line by line

var2 = 10     # assigning new value to the same variable
print("integer overidden: ", var2) # printing

print('\n')     # line break also called escape sequence
# Out:
# integer overidden:  10

# %%
# Float variable
var3 = 3.4
var3
# Out:
# 3.4

# %%
# Boolean variable
var4 = True
var4
# Out:
# True

# %%
# Complex variable
var5 = 3+4j # write j with number to represent complex number
var5
# Out:
# (3+4j)

# %% [markdown]
# #### Data Types in Python
# - type() builtin function is used to check the datatype

# %%
type(var1)
# Out:
# str

# %%
type(var2)
# Out:
# int

# %%
type(var3)
# Out:
# float

# %%
type(var4)
# Out:
# bool

# %%
type(var5)
# Out:
# complex

# %% [markdown]
# ### Converting an abject type to another object type

# %%
# Let's convert the integer number 6 to a string and a float
number = 6

print(str(number)) # convert into string & print
print(float(number)) # convert into float & print
# checking the data type 
print(type(number)) 
print(type(str(number)))
print(type(float(number)))
# Out:
# 6
# 6.0
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# Let's conver the float number 3.14 to a string and an integer
number = 3.14

print(str(number)) # convert into string & print
print(int(number)) # convert into integer & print
# checking the data type 
print(type(number))
print(type(str(number)))
print(type(int(number)))
str(number)

# %% [markdown]
# #### User Input (runtime assigning the value to the variable) using input() function
# - Are used to take input from the user at runtime
# - By default input taken is in string format.
# - in-built function input() is used

# %%
name = input("Enter your name: ")       # Taking input and saving it in variable string type
field = input("Enter your field of interest: ") # Taking input
print("You have bright future in ",field, " ", name,"!") # Printing the user input data
# Out:
# You have bright future in  SCM   Hakeem !

# %% [markdown]
# ## 3- Operators in Python
# ##### 1. Arithmetic 2. Relational 3. Logical

# %% [markdown]
# #### Arithmetic Operators

# %%
a = 20
b = 22

# %%
a + b
# Out:
# 42

# %%
b - a
# Out:
# 2

# %%
b / a
# Out:
# 1.1

# %%
b * a
# Out:
# 440

# %%
print("Addition 2+3 = ", 2+3)       # Adding two numbers
print("Sbutraction 7-2 = ", 7-2)     # subtracting a number from another number
print("Multiplication 2*2 = ", 2*2) # Multiplying two numbers
print("Division 10/4 = ", 10/4)     # Division with reminder
print("Division 10//4 = ", 10//4)   # Division without reminder - Dropping any fractional remainder
print("Exponent 2^8 = ",  2**8)     # 2 power 8 (exponent)
print("Reminder 6/4 = ", 6%4)       # Modulus operator

print("\nComplex equation")
print("equation 2**3/3*4+(2-6) = ", 2**3/3*4+(2-6)) # evaluating complex equation
# Out:
# Addition 2+3 =  5
# Sbutraction 7-2 =  5
# Multiplication 2*2 =  4
# Division 10/4 =  2.5
# Division 10//4 =  2
# Exponent 2^8 =  256
# Reminder 6/4 =  2
#
# Complex equation
# equation 2**3/3*4+(2-6) =  6.666666666666666

# %% [markdown]
# #### Relational Operators

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a < b

# %%
a != b
# Out:
# True

# %% [markdown]
# #### Logical Operators (&, |)

# %%
a = True
b = False
a & b
# Out:
# False

# %%
a | b
# Out:
# True

# %%
a = True
b = True
a & b
# Out:
# True

# %% [markdown]
# Operator precedence in python is:
# **PEMDAS** 1-Paranthesis, 2-Exponent, 3-Multiplication, 4-Division, 5-Addition, 5-Subtraction <br>
# Addition and subtraction has same precedence
#
# **Note** python evaluates expression from left to right

# %% [markdown]
# ### Programming Simple Mathematics

# %%
# Computing the growth of money deposited in a bank
# initial amount = 100
# interest rate in % = 5.0
# the number of years = 7
print(100*(1 + 5.0/100)**7)
# Out:
# 140.71004226562505

# %% [markdown]
# ## 4- Importing Modules
# - math module
# - datetime module

# %% [markdown]
# ### Math Module

# %%
import math
r = math.sqrt(2)
# or
from math import sqrt
r = sqrt(2)
# or
from math import * # import everything in math
r = sqrt(2)

# %%
r
# Out:
# 1.4142135623730951

# %%
# Consider evaluating the bell-shaped (Normal Distribution) Gaussian function
from math import sqrt, pi, exp
mean = 0
sd = 2
x = 1.0
f = 1/(sqrt(2*pi)*sd) * exp(-0.5*((x-mean)/sd)**2)
print(f)
# Out:
# 0.17603266338214976

# %%
# Finding the area of the circle 
# radius of the circle
r = 4
 
# value of pie
pie = math.pi
 
# area of the circle
print(pie * r * r)
# Out:
# 50.26548245743669

# %%
# Finding the factorial of the number
a = 5
# Returning the factorial of 5
print("The factorial of 5 is : ", math.factorial(a))
# Out:
# The factorial of 5 is :  120

# %%
# Returning the Square Root of 5
print("The Square Root of 5 is : ", math.sqrt(a))
# Out:
# The Square Root of 5 is :  2.23606797749979

# %%
# Returning the cube Root of 27
print("The Cube Root of 27 is : ", math.cbrt(27))
# Out:
# The Cube Root of 27 is :  3.0

# %%
# Returning the Combination of 5C2
math.comb(5,2)
# Out:
# 10

# %%
# Return the Euclidean distance between two points p and q.
math.dist((2,3),(3,4))
# Out:
# 1.4142135623730951

# %% [markdown]
# ### Dates and times
# - The built-in Python datetime module provides datetime, date, and time types.
# - The datetime type combines the information stored in date and time

# %%
import datetime

# %%
from datetime import datetime, date, time
dt = datetime(2011, 10, 29, 20, 30, 21) # datetime(year, month, day, hour, minute, second)
dt

# %%
dt.year

# %%
dt.month

# %%
dt.day

# %%
dt.hour

# %%
dt.date() # Year, Month, Day

# %%
dt.time() # return hours, minute, second

# %%
dt.strftime("%Y-%m-%d %H:%M") # strftime method formats a datetime as a string

# %%
dt.strftime("%d/%m/%Y, %H:%M:%S")
